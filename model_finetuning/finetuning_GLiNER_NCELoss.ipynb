# %% [markdown]
# # Adjust GLiNER model with contrastive learning (NCELoss)

# %%
# !pip install gliner
# Out:
# Collecting gliner
#   Downloading gliner-0.2.22-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from gliner) (2.8.0+cu126)
# Collecting transformers<=4.51.0,>=4.38.2 (from gliner)
#   Downloading transformers-4.51.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: huggingface_hub>=0.21.4 in /usr/local/lib/python3.12/dist-packages (from gliner) (0.34.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gliner) (4.67.1)
# Collecting onnxruntime (from gliner)
#   Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from gliner) (0.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.4->gliner) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.4->gliner) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.4->gliner) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.4->gliner) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.4->gliner) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.4->gliner) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.4->gliner) (1.1.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner) (3.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.51.0,>=4.38.2->gliner) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.51.0,>=4.38.2->gliner) (2024.11.6)
# Collecting tokenizers<0.22,>=0.21 (from transformers<=4.51.0,>=4.38.2->gliner)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.51.0,>=4.38.2->gliner) (0.6.2)
# Collecting coloredlogs (from onnxruntime->gliner)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime->gliner) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime->gliner) (5.29.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->gliner) (1.3.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->gliner)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->gliner) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.4->gliner) (2025.8.3)
# Downloading gliner-0.2.22-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.3/76.3 kB 5.4 MB/s eta 0:00:00
# Downloading transformers-4.51.0-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 49.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 38.3 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.7 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, tokenizers, onnxruntime, transformers, gliner
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.0
#     Uninstalling tokenizers-0.22.0:
#       Successfully uninstalled tokenizers-0.22.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.1
#     Uninstalling transformers-4.56.1:
#       Successfully uninstalled transformers-4.56.1
# Successfully installed coloredlogs-15.0.1 gliner-0.2.22 humanfriendly-10.0 onnxruntime-1.22.1 tokenizers-0.21.4 transformers-4.51.0

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.51.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
import os
import json
import random

import torch

from gliner.training import Trainer, TrainingArguments
from model_finetuning.model import ContrastiveGLiNER
from model_finetuning.data_collator import ContrastiveDataCollator

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "true"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
# Load the processed output from the JSON file which contains data ready for training
with open("../new_data/processed_output.json", "r", encoding="utf-8") as file:
    original_data = json.load(file)

print(len(original_data))
print(original_data[0])
# Out:
# 2811
# {'tokenized_text': ['Any', 'part', 'of', 'your', 'neck', 'muscles', ',', 'bones', ',', 'joints', ',', 'tendons', ',', 'ligaments', ',', 'or', 'nerves', 'can', 'cause', 'neck', 'problems', '.', 'Neck', 'pain', 'is', 'very', 'common', '.', 'Pain', 'may', 'also', 'come', 'from', 'your', 'shoulder', ',', 'jaw', ',', 'head', ',', 'or', 'upper', 'arms', '.', 'Muscle', 'strain', 'or', 'tension', 'often', 'causes', 'neck', 'pain', '.', 'The', 'problem', 'is', 'usually', 'overuse', ',', 'such', 'as', 'from', 'sitting', 'at', 'a', 'computer', 'for', 'too', 'long', '.', 'Sometimes', 'you', 'can', 'strain', 'your', 'neck', 'muscles', 'from', 'sleeping', 'in', 'an', 'awkward', 'position', 'or', 'overdoing', 'it', 'during', 'exercise', '.', 'Falls', 'or', 'accidents', ',', 'including', 'car', 'accidents', ',', 'are', 'another', 'common', 'cause', 'of', 'neck', 'pain', '.', 'Whiplash', ',', 'a', 'soft', 'tissue', 'injury', 'to', 'the', 'neck', ',', 'is', 'also', 'called', 'neck', 'sprain', 'or', 'strain', '.', 'Treatment', 'depends', 'on', 'the', 'cause', ',', 'but', 'may', 'include', 'applying', 'ice', ',', 'taking', 'pain', 'relievers', ',', 'getting', 'physical', 'therapy', 'or', 'wearing', 'a', 'cervical', 'collar', '.', 'You', 'rarely', 'need', 'surgery', '.'], 'ner': [[4, 4, 'body part'], [19, 19, 'body part'], [22, 22, 'body part'], [50, 50, 'body part'], [75, 75, 'body part'], [102, 102, 'body part'], [113, 113, 'body part'], [118, 118, 'body part'], [5, 5, 'body part'], [76, 76, 'body part'], [7, 7, 'body part'], [9, 9, 'body part'], [11, 11, 'body part'], [13, 13, 'body part'], [16, 16, 'body part'], [19, 20, 'condition'], [22, 23, 'condition'], [50, 51, 'condition'], [102, 103, 'condition'], [34, 34, 'body part'], [36, 36, 'body part'], [38, 38, 'body part'], [41, 42, 'body part'], [44, 45, 'condition'], [47, 47, 'condition'], [4, 5, 'body part'], [75, 76, 'body part'], [89, 89, 'event'], [91, 91, 'event'], [95, 95, 'event'], [94, 95, 'event'], [105, 105, 'condition'], [108, 110, 'condition'], [118, 119, 'condition'], [45, 45, 'condition'], [73, 73, 'condition'], [121, 121, 'condition'], [133, 133, 'treatment'], [136, 137, 'treatment'], [140, 141, 'treatment'], [145, 146, 'treatment'], [151, 151, 'treatment']], 'negative_ner': [[4, 4, 'condition'], [19, 19, 'condition'], [22, 22, 'condition'], [50, 50, 'condition'], [75, 75, 'condition'], [102, 102, 'condition'], [113, 113, 'condition'], [118, 118, 'condition'], [5, 5, 'event'], [76, 76, 'event'], [7, 7, 'treatment'], [9, 9, 'body part'], [11, 11, 'condition'], [13, 13, 'event'], [16, 16, 'treatment'], [19, 20, 'body part'], [22, 23, 'body part'], [50, 51, 'body part'], [102, 103, 'body part'], [34, 34, 'condition'], [36, 36, 'event'], [38, 38, 'treatment'], [41, 42, 'condition'], [44, 45, 'event'], [47, 47, 'body part'], [4, 5, 'condition'], [75, 76, 'condition'], [89, 89, 'body part'], [91, 91, 'condition'], [95, 95, 'condition'], [94, 95, 'body part'], [105, 105, 'event'], [108, 110, 'body part'], [118, 119, 'event'], [45, 45, 'body part'], [73, 73, 'body part'], [121, 121, 'body part'], [133, 133, 'condition'], [136, 137, 'event'], [140, 141, 'body part'], [145, 146, 'condition'], [151, 151, 'event']]}

# %%
# Load the processed output from the JSON file which contains data ready for training
with open("../data/pilener_data.json", "r", encoding="utf-8") as file:
    pilener_data = json.load(file)

print(len(pilener_data))
print(pilener_data[0])
# Out:
# 45871
# {'tokenized_text': ['Q', ':', 'Position', 'character', 'based', 'on', 'enemy', 'coordinates', 'in', 'lua', 'I', 'have', 'written', 'a', 'function', 'here', 'which', 'should', 'turn', 'my', 'character', 'based', 'on', 'enemy', 'coordinates', 'but', 'it', "'", 's', 'not', 'perfect', 'because', 'it', 'does', 'not', 'always', 'turn', 'where', 'I', 'want', 'it', 'to', 'and', 'perhaps', 'there', 'is', 'a', 'better', 'way', 'of', 'writing', 'it', 'local', 'myPosition', '=', '{', 'x', '=', '350', ',', 'y', '=', '355', '}', 'local', 'enemyPosition', '=', '{', 'x', '=', '352', ',', 'y', '=', '354', '}', 'local', 'xValue', ',', 'yValue', ',', 'xDir', ',', 'yDir', ',', 'dir', 'if', 'myPosition', '.', 'x', '>', 'enemyPosition', '.', 'x', 'then', 'xValue', '=', 'myPosition', '.', 'x', '-', 'enemyPosition', '.', 'x', 'elseif', 'myPosition', '.', 'x', '<', 'enemyPosition', '.', 'x', 'then', 'xValue', '=', 'myPosition', '.', 'x', '-', 'enemyPosition', '.', 'x', 'else', 'xValue', '=', '0', 'end', 'if', 'myPosition', '.', 'y', '>', 'enemyPosition', '.', 'y', 'then', 'yValue', '=', 'myPosition', '.', 'y', '-', 'enemyPosition', '.', 'y', 'elseif', 'myPosition', '.', 'y', '<', 'enemyPosition', '.', 'y', 'then', 'yValue', '=', 'myPosition', '.', 'y', '-', 'enemyPosition', '.', 'y', 'else', 'yValue', '=', '0', 'end', 'if', 'xValue', '<', '0', 'then', 'xDir', '=', '"', 'TURN', 'RIGHT', '"', 'elseif', 'xValue', '>', '0', 'then', 'xDir', '=', '"', 'TURN', 'LEFT', '"', 'end', 'if', 'yValue', '<', '0', 'then', 'yDir', '=', '"', 'TURN', 'DOWN', '"', 'elseif', 'yValue', '>', '0', 'then', 'yDir', '=', '"', 'TURN', 'UP', '"', 'end', 'if', 'xValue', '>', 'yValue', 'then', 'dir', '=', 'xDir', 'elseif', 'xValue', 'dir', '=', 'yDir', 'end', 'print', '(', '"', 'Turn', ':', '"', '.', '.', 'dir', ')', 'And', 'here', 'you', 'have', 'some', 'pictures', 'to', 'further', 'illustrate', 'what', 'I', 'have', 'in', 'mind', ':', 'As', 'you', 'can', 'see', 'on', 'the', 'pictures', ',', 'direction', 'depends', 'on', 'the', 'higher', 'number', '.'], 'ner': [[14, 14, 'programming concept'], [9, 9, 'programming language'], [53, 53, 'variable'], [87, 87, 'variable'], [97, 97, 'variable'], [105, 105, 'variable'], [115, 115, 'variable'], [128, 128, 'variable'], [138, 138, 'variable'], [146, 146, 'variable'], [156, 156, 'variable'], [65, 65, 'variable'], [91, 91, 'variable'], [101, 101, 'variable'], [109, 109, 'variable'], [119, 119, 'variable'], [132, 132, 'variable'], [142, 142, 'variable'], [150, 150, 'variable'], [160, 160, 'variable'], [77, 77, 'variable'], [95, 95, 'variable'], [113, 113, 'variable'], [123, 123, 'variable'], [169, 169, 'variable'], [180, 180, 'variable'], [215, 215, 'variable'], [223, 223, 'variable'], [79, 79, 'variable'], [136, 136, 'variable'], [154, 154, 'variable'], [164, 164, 'variable'], [192, 192, 'variable'], [203, 203, 'variable'], [217, 217, 'variable'], [81, 81, 'variable'], [173, 173, 'variable'], [184, 184, 'variable'], [221, 221, 'variable'], [83, 83, 'variable'], [196, 196, 'variable'], [207, 207, 'variable'], [226, 226, 'variable'], [85, 85, 'variable'], [219, 219, 'variable'], [224, 224, 'variable'], [236, 236, 'variable']], 'negative': ['database', 'Date']}

# %%
random.shuffle(original_data)
random.shuffle(pilener_data)

# %%
limited_original = original_data[:2250] if len(original_data) >= 2250 else original_data
limited_pilener = pilener_data[:4500] if len(pilener_data) >= 4500 else pilener_data

# %%
batch_size = 8

# %%
original_chunks = [limited_original[i:i+batch_size] for i in range(0, len(limited_original), batch_size)]
pilener_chunks = [limited_pilener[i:i+batch_size] for i in range(0, len(limited_pilener), batch_size)]

# %%
len(pilener_chunks)

# %%
combined_data = []
original_idx = 0
pilener_idx = 0

while original_idx < len(original_chunks) or pilener_idx < len(pilener_chunks):
    
    # Add 1 batch of original data
    if original_idx < len(original_chunks):
        combined_data.extend(original_chunks[original_idx])
        original_idx += 1
    
    # Add 2 batches of pilener data
    for _ in range(2):
        if pilener_idx < len(pilener_chunks):
            combined_data.extend(pilener_chunks[pilener_idx])
            pilener_idx += 1
    
    # Stop if we've used all original data (since pilener is 2x larger)
    if original_idx >= len(original_chunks):
        # Add remaining pilener batches
        while pilener_idx < len(pilener_chunks):
            combined_data.extend(pilener_chunks[pilener_idx])
            pilener_idx += 1
        break

# %%
combined_data[-17]

# %%
processed_output = combined_data

# %%
train_dataset = processed_output[:int(len(processed_output)*0.8)]
val_dataset = processed_output[int(len(processed_output)*0.8):int(len(processed_output)*0.9)]
test_dataset = processed_output[int(len(processed_output)*0.9):]

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

# %%
gliner_model = ContrastiveGLiNER.from_pretrained("urchade/gliner_small")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md: 0.00B [00:00, ?B/s]
# gliner_config.json:   0%|          | 0.00/477 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/611M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:559: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
gliner_model.config
# Out:
# GLiNERConfig {
#   "class_token_index": 128002,
#   "decoder_mode": null,
#   "dropout": 0.4,
#   "embed_ent_token": true,
#   "encoder_config": {
#     "_attn_implementation_autoset": true,
#     "_name_or_path": "microsoft/deberta-v3-small",
#     "add_cross_attention": false,
#     "architectures": null,
#     "attention_probs_dropout_prob": 0.1,
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": null,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_eps": 1e-07,
#     "legacy": true,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 512,
#     "max_relative_positions": -1,
#     "min_length": 0,
#     "model_type": "deberta-v2",
#     "no_repeat_ngram_size": 0,
#     "norm_rel_ebd": "layer_norm",
#     "num_attention_heads": 12,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_hidden_layers": 6,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 0,
#     "pooler_dropout": 0,
#     "pooler_hidden_act": "gelu",
#     "pooler_hidden_size": 768,
#     "pos_att_type": [
#       "p2c",
#       "c2p"
#     ],
#     "position_biased_input": false,
#     "position_buckets": 256,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "relative_attention": true,
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "share_att_key": true,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "type_vocab_size": 0,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "vocab_size": 128004
#   },
#   "ent_token": "<<ENT>>",
#   "eval_every": 5000,
#   "fine_tune": true,
#   "full_decoder_context": true,
#   "fuse_layers": false,
#   "has_rnn": true,
#   "hidden_size": 512,
#   "labels_decoder": null,
#   "labels_decoder_config": null,
#   "labels_encoder": null,
#   "labels_encoder_config": null,
#   "lr_encoder": "1e-5",
#   "lr_others": "5e-5",
#   "max_len": 384,
#   "max_neg_type_ratio": 1,
#   "max_types": 25,
#   "max_width": 12,
#   "model_name": "microsoft/deberta-v3-small",
#   "model_type": "gliner",
#   "name": "correct",
#   "num_post_fusion_layers": 1,
#   "num_steps": 30000,
#   "post_fusion_schema": "",
#   "random_drop": true,
#   "sep_token": "<<SEP>>",
#   "shuffle_types": true,
#   "size_sup": -1,
#   "span_mode": "markerV0",
#   "subtoken_pooling": "first",
#   "train_batch_size": 8,
#   "transformers_version": "4.51.0",
#   "vocab_size": 128004,
#   "warmup_ratio": 3000,
#   "words_splitter_type": "whitespace"
# }

# %%
gliner_model.to(device)
# Out:
# ContrastiveGLiNER(
#   (model): SpanModel(
#     (token_rep_layer): Encoder(
#       (bert_layer): Transformer(
#         (model): DebertaV2Model(
#           (embeddings): DebertaV2Embeddings(
#             (word_embeddings): Embedding(128004, 768, padding_idx=0)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (encoder): DebertaV2Encoder(
#             (layer): ModuleList(
#               (0-5): 6 x DebertaV2Layer(
#                 (attention): DebertaV2Attention(
#                   (self): DisentangledSelfAttention(
#                     (query_proj): Linear(in_features=768, out_features=768, bias=True)
#                     (key_proj): Linear(in_features=768, out_features=768, bias=True)
#                     (value_proj): Linear(in_features=768, out_features=768, bias=True)
#                     (pos_dropout): Dropout(p=0.1, inplace=False)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): DebertaV2SelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): DebertaV2Intermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): DebertaV2Output(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#             )
#             (rel_embeddings): Embedding(512, 768)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#           )
#         )
#       )
#       (projection): Linear(in_features=768, out_features=512, bias=True)
#     )
#     (rnn): LstmSeq2SeqEncoder(
#       (lstm): LSTM(512, 256, batch_first=True, bidirectional=True)
#     )
#     (span_rep_layer): SpanRepLayer(
#       (span_rep_layer): SpanMarkerV0(
#         (project_start): Sequential(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.4, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (project_end): Sequential(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.4, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (out_project): Sequential(
#           (0): Linear(in_features=1024, out_features=2048, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.4, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#         )
#       )
#     )
#     (prompt_rep_layer): Sequential(
#       (0): Linear(in_features=512, out_features=2048, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.4, inplace=False)
#       (3): Linear(in_features=2048, out_features=512, bias=True)
#     )
#   )
#   (infonce_loss): InfoNCELoss()
# )

# %%
data_collator = ContrastiveDataCollator(gliner_model.config, data_processor=gliner_model.data_processor, prepare_labels=True)

# %%
num_steps = 17000
data_size = len(train_dataset) # 5400
num_batches = data_size // batch_size
num_epochs = max(1, num_steps // num_batches)

# %%
num_epochs
# Out:
# 15

# %%
training_args = TrainingArguments(
    output_dir="contrastive_gliner_model",
    learning_rate=5e-5,
    weight_decay=0.01,
    lr_scheduler_type="linear",
    warmup_ratio=0.1,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_epochs,
    dataloader_num_workers=0,
    use_cpu=False,
    report_to="none",
    save_strategy="steps",
    eval_strategy="steps",
    eval_steps=500,
    save_steps=500,
    load_best_model_at_end=False,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    save_total_limit=3,
)

# %%
import torch
from transformers import TrainerCallback

class ClearCacheCallback(TrainerCallback):
    def on_step_end(self, args, state, control, **kwargs):
        torch.cuda.empty_cache()

# %%
trainer = Trainer(
    model=gliner_model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=gliner_model.data_processor.transformer_tokenizer,
    data_collator=data_collator,
    callbacks=[ClearCacheCallback()]
)
# Out:
# /tmp/ipython-input-4267558522.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
print("Allocated memory:", torch.cuda.memory_allocated() / 1024**3, "GB")
# Out:
# Allocated memory: 0.56866455078125 GB

# %%
torch.cuda.empty_cache()

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 424 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1018 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
#     <div>
#
#       <progress value='5055' max='5055' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5055/5055 1:57:38, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>338</td>
#       <td>No log</td>
#       <td>189575.046875</td>
#     </tr>
#     <tr>
#       <td>676</td>
#       <td>256861.344000</td>
#       <td>206491.171875</td>
#     </tr>
#     <tr>
#       <td>1014</td>
#       <td>132599.920000</td>
#       <td>198401.656250</td>
#     </tr>
#     <tr>
#       <td>1352</td>
#       <td>132599.920000</td>
#       <td>208670.437500</td>
#     </tr>
#     <tr>
#       <td>1690</td>
#       <td>131958.240000</td>
#       <td>204255.812500</td>
#     </tr>
#     <tr>
#       <td>2028</td>
#       <td>132877.784000</td>
#       <td>201814.218750</td>
#     </tr>
#     <tr>
#       <td>2366</td>
#       <td>132877.784000</td>
#       <td>194990.484375</td>
#     </tr>
#     <tr>
#       <td>2704</td>
#       <td>134459.600000</td>
#       <td>195829.390625</td>
#     </tr>
#     <tr>
#       <td>3042</td>
#       <td>133712.544000</td>
#       <td>194346.609375</td>
#     </tr>
#     <tr>
#       <td>3380</td>
#       <td>133712.544000</td>
#       <td>211335.734375</td>
#     </tr>
#     <tr>
#       <td>3718</td>
#       <td>134581.120000</td>
#       <td>196806.093750</td>
#     </tr>
#     <tr>
#       <td>4056</td>
#       <td>131614.776000</td>
#       <td>209799.093750</td>
#     </tr>
#     <tr>
#       <td>4394</td>
#       <td>131614.776000</td>
#       <td>214080.046875</td>
#     </tr>
#     <tr>
#       <td>4732</td>
#       <td>133751.112000</td>
#       <td>198857.406250</td>
#     </tr>
#   </tbody>
# </table><p>
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 578 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 513 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1004 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 641 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 405 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 419 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 767 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 511 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 757 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 877 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 724 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 397 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 636 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 517 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1084 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1541 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 531 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 470 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 655 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1242 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 926 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 524 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 577 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1006 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 444 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 429 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 703 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 423 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 576 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 800 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 392 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1237 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 816 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 956 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 503 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 861 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 959 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 427 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 858 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 620 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 708 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1083 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 402 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 462 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1017 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 908 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 770 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 640 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1253 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 555 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 473 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 401 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 424 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 406 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 485 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 855 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 501 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 720 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 748 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 889 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 934 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 997 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 533 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 712 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1257 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 661 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 453 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 957 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 459 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 753 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 741 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 510 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1321 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1232 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 479 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 669 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 895 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 433 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1286 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1015 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 928 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 523 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 587 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 930 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 478 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 819 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 394 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 585 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 396 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 672 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1035 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 436 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 500 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 761 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 491 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 891 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1389 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 567 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 538 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1315 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 684 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 565 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 948 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1143 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 490 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 589 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 499 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1461 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1093 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1307 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1330 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 562 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 471 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 677 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1038 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 792 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 617 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 662 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 447 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1051 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1946 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 619 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 420 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 874 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 868 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 713 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 667 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 488 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 606 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 528 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 2189 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 512 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 415 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1426 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 851 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1059 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 417 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 693 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 521 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 900 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 395 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 497 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 653 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1008 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 896 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1475 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1887 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 450 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 574 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 618 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1166 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 390 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 828 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 625 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1215 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 385 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 823 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 549 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 887 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 686 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1167 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 504 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 604 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 544 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 632 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 630 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 737 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 449 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 818 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 432 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 542 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 710 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 654 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 760 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1035 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1330 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 2189 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1257 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 429 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 518 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 956 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 934 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 930 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 453 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1038 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 510 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 406 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 419 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1315 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1084 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 703 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 420 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 959 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1461 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 512 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 931 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 462 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 511 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 587 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 478 has been truncated to 384
# ...
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 724 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 491 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 792 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1257 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 427 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 908 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 406 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 577 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 402 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 662 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 708 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 562 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 453 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 575 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 741 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 420 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 926 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1389 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 661 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 948 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 957 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 587 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 816 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1035 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 655 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1093 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 433 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 928 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 997 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 748 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 757 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 567 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 861 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 667 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1426 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 405 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1307 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 617 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 436 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1541 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1286 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1242 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 578 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1006 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 444 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 555 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 733 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 576 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 424 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1232 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 712 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1017 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 635 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 488 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 531 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 524 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 761 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1237 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 515 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 819 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 538 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 770 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 1143 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 2189 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 523 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 703 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 490 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 677 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# /usr/local/lib/python3.12/dist-packages/gliner/data_processing/processor.py:351: UserWarning: Sentence of length 956 has been truncated to 384
#   warnings.warn(f"Sentence of length {len(tokens)} has been truncated to {max_len}")
# TrainOutput(global_step=5055, training_loss=145305.34272997032, metrics={'train_runtime': 7062.513, 'train_samples_per_second': 5.724, 'train_steps_per_second': 0.716, 'total_flos': 0.0, 'train_loss': 145305.34272997032, 'epoch': 15.0})

# %%
trainer.save_model("finetuned_gliner_model_NCELoss")

# %%
best_ckpt = trainer.state.best_model_checkpoint
print(best_ckpt)
# Out:
# contrastive_gliner_model/checkpoint-338

# %%
# !zip -r finetuned_gliner_model_NCELoss.zip finetuned_gliner_model_NCELoss
from google.colab import files
files.download("finetuned_gliner_model_NCELoss.zip")
# Out:
#   adding: finetuned_gliner_model_NCELoss3/ (stored 0%)
#   adding: finetuned_gliner_model_NCELoss3/added_tokens.json (deflated 36%)
#   adding: finetuned_gliner_model_NCELoss3/pytorch_model.bin (deflated 9%)
#   adding: finetuned_gliner_model_NCELoss3/special_tokens_map.json (deflated 50%)
#   adding: finetuned_gliner_model_NCELoss3/spm.model (deflated 50%)
#   adding: finetuned_gliner_model_NCELoss3/gliner_config.json (deflated 65%)
#   adding: finetuned_gliner_model_NCELoss3/tokenizer.json (deflated 77%)
#   adding: finetuned_gliner_model_NCELoss3/tokenizer_config.json (deflated 79%)

# %%
trained_model = ContrastiveGLiNER.from_pretrained("finetuned_gliner_model_NCELoss", load_tokenizer=True)
# Out:
# config.json not found in /content/finetuned_gliner_model_NCELoss3
# WARNING:huggingface_hub.hub_mixin:config.json not found in /content/finetuned_gliner_model_NCELoss3

# %%
with open("../new_data/json_outputs.json", "r", encoding="utf-8") as file:
    json_outputs = json.load(file)

print(len(json_outputs))
print(json_outputs[0]['entities'][0]['types'])
# Out:
# 2811
# ['body part']

# %%
json_outputs[0]
# Out:
# {'text': 'Any part of your neck  muscles, bones, joints, tendons, ligaments, or nerves  can cause neck problems. Neck pain is very common. Pain may also come from your shoulder, jaw, head, or upper arms. Muscle strain or tension often causes neck pain. The problem is usually overuse, such as from sitting at a computer for too long. Sometimes you can strain your neck muscles from sleeping in an awkward position or overdoing it during exercise. Falls or accidents, including car accidents, are another common cause of neck pain. Whiplash, a soft tissue injury to the neck, is also called neck sprain or strain. Treatment depends on the cause, but may include applying ice, taking pain relievers, getting physical therapy or wearing a cervical collar. You rarely need surgery.',
#  'entities': [{'entity': 'neck', 'types': ['body part']},
#   {'entity': 'muscles', 'types': ['body part']},
#   {'entity': 'bones', 'types': ['body part']},
#   {'entity': 'joints', 'types': ['body part']},
#   {'entity': 'tendons', 'types': ['body part']},
#   {'entity': 'ligaments', 'types': ['body part']},
#   {'entity': 'nerves', 'types': ['body part']},
#   {'entity': 'neck problems', 'types': ['condition']},
#   {'entity': 'neck pain', 'types': ['condition']},
#   {'entity': 'shoulder', 'types': ['body part']},
#   {'entity': 'jaw', 'types': ['body part']},
#   {'entity': 'head', 'types': ['body part']},
#   {'entity': 'upper arms', 'types': ['body part']},
#   {'entity': 'Muscle strain', 'types': ['condition']},
#   {'entity': 'tension', 'types': ['condition']},
#   {'entity': 'neck muscles', 'types': ['body part']},
#   {'entity': 'Falls', 'types': ['event']},
#   {'entity': 'accidents', 'types': ['event']},
#   {'entity': 'car accidents', 'types': ['event']},
#   {'entity': 'Whiplash', 'types': ['condition']},
#   {'entity': 'soft tissue injury', 'types': ['condition']},
#   {'entity': 'neck sprain', 'types': ['condition']},
#   {'entity': 'strain', 'types': ['condition']},
#   {'entity': 'ice', 'types': ['treatment']},
#   {'entity': 'pain relievers', 'types': ['treatment']},
#   {'entity': 'physical therapy', 'types': ['treatment']},
#   {'entity': 'cervical collar', 'types': ['treatment']},
#   {'entity': 'surgery', 'types': ['treatment']}],
#  'negative_entities': [{'entity': 'neck', 'types': ['condition']},
#   {'entity': 'muscles', 'types': ['event']},
#   {'entity': 'bones', 'types': ['treatment']},
#   {'entity': 'joints', 'types': ['body part']},
#   {'entity': 'tendons', 'types': ['condition']},
#   {'entity': 'ligaments', 'types': ['event']},
#   {'entity': 'nerves', 'types': ['treatment']},
#   {'entity': 'neck problems', 'types': ['body part']},
#   {'entity': 'neck pain', 'types': ['body part']},
#   {'entity': 'shoulder', 'types': ['condition']},
#   {'entity': 'jaw', 'types': ['event']},
#   {'entity': 'head', 'types': ['treatment']},
#   {'entity': 'upper arms', 'types': ['condition']},
#   {'entity': 'Muscle strain', 'types': ['event']},
#   {'entity': 'tension', 'types': ['body part']},
#   {'entity': 'neck muscles', 'types': ['condition']},
#   {'entity': 'Falls', 'types': ['body part']},
#   {'entity': 'accidents', 'types': ['condition']},
#   {'entity': 'car accidents', 'types': ['body part']},
#   {'entity': 'Whiplash', 'types': ['event']},
#   {'entity': 'soft tissue injury', 'types': ['body part']},
#   {'entity': 'neck sprain', 'types': ['event']},
#   {'entity': 'strain', 'types': ['body part']},
#   {'entity': 'ice', 'types': ['condition']},
#   {'entity': 'pain relievers', 'types': ['event']},
#   {'entity': 'physical therapy', 'types': ['body part']},
#   {'entity': 'cervical collar', 'types': ['condition']},
#   {'entity': 'surgery', 'types': ['event']}]}

# %%
entity_types_per_text = []
for i, output in enumerate(json_outputs):
  if i == 15:
    break
  entity_types = []
  for j, entity in enumerate(json_outputs[i]['entities']):
    for k, entity_type in enumerate(entity['types']):
      entity_types.append(entity_type)

  entity_types_per_text.append(
      {
          'text': output['text'],
          'entity_types': set(entity_types)
       }
      )

entity_types_per_text
# Out:
# [{'text': 'Any part of your neck  muscles, bones, joints, tendons, ligaments, or nerves  can cause neck problems. Neck pain is very common. Pain may also come from your shoulder, jaw, head, or upper arms. Muscle strain or tension often causes neck pain. The problem is usually overuse, such as from sitting at a computer for too long. Sometimes you can strain your neck muscles from sleeping in an awkward position or overdoing it during exercise. Falls or accidents, including car accidents, are another common cause of neck pain. Whiplash, a soft tissue injury to the neck, is also called neck sprain or strain. Treatment depends on the cause, but may include applying ice, taking pain relievers, getting physical therapy or wearing a cervical collar. You rarely need surgery.',
#   'entity_types': {'body part', 'condition', 'event', 'treatment'}},
#  {'text': "Heel problems are common and can be painful. Often, they result from too much stress on your heel bone and the tissues that surround it. That stress can come from  Injuries  Bruises that you get walking, running or jumping  Wearing shoes that don't fit or aren't made well  Being overweight These can lead to tendinitis, bursitis, and fasciitis, which are all types of inflammation of the tissues that surround your heel. Over time the stress can cause bone spurs and deformities. Certain diseases, such as rheumatoid arthritis and gout, can also lead to heel problems. Treatments for heel problems might include rest, medicines, exercises, taping, and special shoes. Surgery is rarely needed.",
#   'entity_types': {'body part', 'condition', 'disease', 'treatment'}},
#  {'text': 'Summary : Computed tomography (CT) is a type of imaging. It uses special xray equipment to make crosssectional pictures of your body. Doctors use CT scans to look for  Broken bones  Cancers  Blood clots  Signs of heart disease  Internal bleeding During a CT scan, you lie still on a table. The table slowly passes through the center of a large Xray machine. The test is painless. During some tests you receive a contrast dye, which makes parts of your body show up better in the image. NIH: National Cancer Institute',
#   'entity_types': {'condition',
#    'equipment',
#    'imaging',
#    'medical substance',
#    'medical test',
#    'organization',
#    'type of imaging'}},
#  {'text': "Selfharm refers to a person's harming their own body on purpose. About 1 in 100 people hurts himself or herself in this way. More females hurt themselves than males. A person who selfharms usually does not mean to kill himself or herself. But they are at higher risk of attempting suicide if they do not get help. Selfharm tends to begin in teen or early adult years. Some people may engage in selfharm a few times and then stop. Others engage in it more often and have trouble stopping. Examples of selfharm include  Cutting yourself (such as using a razor blade, knife, or other sharp object to cut the skin)  Punching yourself or punching things (like a wall)  Burning yourself with cigarettes, matches, or candles  Pulling out your hair  Poking objects through body openings  Breaking your bones or bruising yourself Many people cut themselves because it gives them a sense of relief. Some people use cutting as a means to cope with a problem. Some teens say that when they hurt themselves, they are trying to stop feeling lonely, angry, or hopeless. It is possible to overcome the urge to hurt yourself. There are other ways to find relief and cope with your emotions. Counseling may help. Dept. of Health and Human Services, Office on Women's Health",
#   'entity_types': {'act',
#    'age group',
#    'feeling',
#    'gender',
#    'object',
#    'organization',
#    'treatment'}},
#  {'text': "Summary : People in the U.S. are living longer than ever before. Many seniors live active and healthy lives. But there's no getting around one thing: as we age, our bodies and minds change. There are things you can do to stay healthy and active as you age.It is important to understand what to expect. Some changes may just be part of normal aging, while others may be a warning sign of a medical problem. It is important to know the difference, and to let your healthcare provider know if you have any concerns. Having a healthy lifestyle can help you to deal with normal aging changes and make the most of your life.",
#   'entity_types': {'location', 'person profession'}},
#  {'text': 'Panic disorder is a type of anxiety disorder. It causes panic attacks, which are sudden feelings of terror when there is no real danger. You may feel as if you are losing control. You may also have physical symptoms, such as  Fast heartbeat  Chest or stomach pain  Breathing difficulty  Weakness or dizziness  Sweating  Feeling hot or a cold chill  Tingly or numb hands Panic attacks can happen anytime, anywhere, and without warning. You may live in fear of another attack and may avoid places where you have had an attack. For some people, fear takes over their lives and they cannot leave their homes. Panic disorder is more common in women than men. It usually starts when people are young adults. Sometimes it starts when a person is under a lot of stress. Most people get better with treatment. Therapy can show you how to recognize and change your thinking patterns before they lead to panic. Medicines can also help. NIH: National Institute of Mental Health',
#   'entity_types': {'anxiety disorder',
#    'organization',
#    'panic attack',
#    'physical symptom'}},
#  {'text': 'Leishmaniasis is a parasitic disease spread by the bite of infected sand flies. There are several different forms of leishmaniasis. The most common are cutaneous and visceral. The cutaneous type causes skin sores. The visceral type affects internal organs such as the spleen, liver, and bone marrow. People with this form usually have fever, weight loss, and an enlarged spleen and liver. Leishmaniasis is found in parts of about 88 countries. Most of these countries are in the tropics and subtropics. It is possible but very unlikely that you would get this disease in the United States. But you should be aware of it if you are traveling to the Middle East or parts of Central America, South America, Asia, Africa or southern Europe. Treatment is with medicines that contain antimony, a type of metal, or with strong antibiotics. The best way to prevent the disease is to protect yourself from sand fly bites:  Stay indoors from dusk to dawn, when sand flies are the most active  Wear long pants and longsleeved shirts when outside  Use insect repellent and bed nets as needed Centers for Disease Control and Prevention',
#   'entity_types': {'disease',
#    'disease form',
#    'location',
#    'metal',
#    'organ',
#    'organization'}},
#  {'text': 'An aneurysm is a bulge or "ballooning" in the wall of an artery. Arteries are blood vessels that carry oxygenrich blood from the heart to other parts of the body. If an aneurysm grows large, it can burst and cause dangerous bleeding or even death. Most aneurysms are in the aorta, the main artery that runs from the heart through the chest and abdomen. There are two types of aortic aneurysm:  Thoracic aortic aneurysms  these occur in the part of the aorta running through the chest  Abdominal aortic aneurysms  these occur in the part of the aorta running through the abdomen Most aneurysms are found during tests done for other reasons. Some people are at high risk for aneurysms. It is important for them to get screening, because aneurysms can develop and become large before causing any symptoms Screening is recommended for people between the ages of 65 and 75 if they have a family history, or if they are men who have smoked. Doctors use imaging tests to find aneurysms. Medicines and surgery are the two main treatments. NIH: National Heart, Lung, and Blood Institute',
#   'entity_types': {'body part',
#    'disease',
#    'location',
#    'medical condition',
#    'medical procedure',
#    'organization',
#    'person type',
#    'profession',
#    'symptom',
#    'treatment'}},
#  {'text': "Summary : It seems to happen almost every day  you hear about the results of a new medical research study. Sometimes the results of one study seem to disagree with the results of another study. It's important to be critical when reading or listening to reports of new medical findings. Some questions that can help you evaluate health information include:  Was the study in animals or people?  Does the study include people like you?  How big was the study?  Was it a randomized controlled clinical trial?  Where was the research done?  If a new treatment was being tested, were there side effects?  Who paid for the research?  Who is reporting the results? NIH: National Institutes of Health",
#   'entity_types': {'intervention',
#    'organization',
#    'outcome',
#    'research type',
#    'subject group'}},
#  {'text': 'Corns and calluses are caused by pressure or friction on your skin. They often appear on feet where the bony parts of your feet rub against your shoes. Corns usually appear on the tops or sides of toes while calluses form on the soles of feet. Calluses also can appear on hands or other areas that are rubbed or pressed. Wearing shoes that fit better or using nonmedicated pads may help. While bathing, gently rub the corn or callus with a washcloth or pumice stone to help reduce the size. To avoid infection, do not try to shave off the corn or callus. See your doctor, especially if you have diabetes or circulation problems. NIH: National Institute on Aging',
#   'entity_types': {'body part', 'condition', 'object', 'organization'}},
#  {'text': "Giardiasis is an illness caused by a parasite called Giardia intestinalis. It lives in soil, food, and water. It may also be on surfaces that have been contaminated with waste. You can become infected if you swallow the parasite. You can also get it if you're exposed to human feces (poop) through sexual contact. The risk of getting giardia is higher for travelers to countries where it is common, people in child care settings, and those who drink untreated water. Diarrhea is the main symptom of giardia infection. Others include  Passing gas  Greasy stools  Stomach cramps  Upset stomach or nausea These symptoms may lead to weight loss and loss of body fluids. Some people have no symptoms at all. Symptoms of infection often last two to six weeks. Stool sample tests can diagnose it. You often need to collect several samples to test. Doctors use several drugs to treat it. The best way to prevent giardia infection is to practice good hygiene, including frequent hand washing. You should not drink water that may be contaminated. You should also peel or wash fresh fruit and vegetables before eating. Centers for Disease Control and Prevention",
#   'entity_types': {'activity',
#    'behavior',
#    'condition',
#    'duration',
#    'environment',
#    'food',
#    'illness',
#    'institution',
#    'location',
#    'medical sample',
#    'medical test',
#    'medication',
#    'object',
#    'organism',
#    'organization',
#    'parasite',
#    'people',
#    'practice',
#    'procedure',
#    'profession',
#    'substance',
#    'symptom'}},
#  {'text': 'Summary : Your kidneys make urine by filtering wastes and extra water from your blood. The waste is called urea. Your blood carries it to the kidneys. From the kidneys, urine travels down two thin tubes called ureters to the bladder. The bladder stores urine until you are ready to urinate. It swells into a round shape when it is full and gets smaller when empty. If your urinary system is healthy, your bladder can hold up to 16 ounces (2 cups) of urine comfortably for 2 to 5 hours. You may have problems with urination if you have  Kidney failure  Urinary tract infections  An enlarged prostate  Bladder control problems like incontinence, overactive bladder, or interstitial cystitis  A blockage that prevents you from emptying your bladder Some conditions may also cause you to have blood or protein in your urine. If you have a urinary problem, see your healthcare provider. Urinalysis and other urine tests can help to diagnose the problem. Treatment depends on the cause. NIH: National Institute of Diabetes and Digestive and Kidney Diseases',
#   'entity_types': {'body fluid',
#    'body part',
#    'chemical compound',
#    'medical condition',
#    'medical test',
#    'molecule',
#    'organ',
#    'organization',
#    'substance'}},
#  {'text': 'Learning disorders affect how a person understands, remembers and responds to new information. People with learning disorders may have problems  Listening or paying attention  Speaking  Reading or writing  Doing math Although learning disorders occur in very young children, they are usually not recognized until the child reaches school age. About onethird of children who have learning disabilities also have ADHD, which makes it hard to focus. Evaluation and testing by a trained professional can help identify a learning disorder. The next step is special education, which involves helping your child in the areas where he or she needs the most help. Sometimes tutors or speech or language therapists also work with the children. Learning disorders do not go away, but strategies to work around them can make them less of a problem. NIH: National Institute of Neurological Disorders and Stroke',
#   'entity_types': {'medical condition', 'organization'}},
#  {'text': "An abscess is a pocket of pus. You can get an abscess almost anywhere in your body. When an area of your body becomes infected, your body's immune system tries to fight the infection. White blood cells go to the infected area, collect within the damaged tissue, and cause inflammation. During this process, pus forms. Pus is a mixture of living and dead white blood cells, germs, and dead tissue. Bacteria, viruses, parasites and swallowed objects can all lead to abscesses. Skin abscesses are easy to detect. They are red, raised and painful. Abscesses inside your body may not be obvious and can damage organs, including the brain, lungs and others. Treatments include drainage and antibiotics.",
#   'entity_types': {'biological agent',
#    'biological structure',
#    'biological substance',
#    'biological system',
#    'medical condition',
#    'object',
#    'substance',
#    'treatment'}},
#  {'text': "Summary : Most men need to pay more attention to their health. Compared to women, men are more likely to  Smoke and drink  Make unhealthy or risky choices  Put off regular checkups and medical care There are also health conditions that only affect men, such as prostate cancer and low testosterone. Many of the major health risks that men face  like colon cancer or heart disease  can be prevented and treated with early diagnosis. Screening tests can find diseases early, when they are easier to treat. It's important to get the screening tests you need.",
#   'entity_types': {'group', 'health behavior', 'health condition'}}]

# %%
for item in entity_types_per_text:
  entities = trained_model.predict_entities(item['text'], list(item['entity_types']), threshold=0.5)
  # print(item['text'])
  # print(item['entity_types'])
  for entity in entities:
    print(entity["text"], "=>", entity["label"])
  print("____________________________")
# Out:
# Any part of your neck  muscles, => body part
# bones, joints, tendons, ligaments, => body part
# or => body part
# nerves  can => body part
# cause neck problems. Neck pain is => body part
# very => body part
# common. Pain may also come from your shoulder, => body part
# jaw, => body part
# head, => body part
# or => body part
# upper arms. Muscle strain or => body part
# tension often causes neck pain. The problem is usually overuse, => body part
# such => body part
# as => body part
# from => body part
# sitting at a computer for => body part
# too => body part
# long. Sometimes you can strain your neck muscles from sleeping in => body part
# an => body part
# awkward => body part
# position or overdoing it during exercise. Falls or accidents, => body part
# including => body part
# car accidents, => body part
# are => body part
# another => body part
# common cause of neck pain. Whiplash, => body part
# a => body part
# soft tissue injury to => body part
# the neck, => body part
# is => body part
# also => body part
# called => body part
# neck sprain or => body part
# strain. Treatment depends on the cause, => body part
# but => body part
# may => body part
# include => body part
# applying => body part
# ice, => body part
# taking pain relievers, => body part
# getting physical therapy or wearing a cervical collar. You rarely => body part
# need => body part
# surgery => body part
# . => body part
# ____________________________
# Heel problems are common and can be painful. Often, => body part
# they => body part
# result from => body part
# too => body part
# much => body part
# stress on => body part
# your => body part
# heel bone and => body part
# the tissues that => body part
# surround it => body part
# . => body part
# That => body part
# stress can => body part
# come from  Injuries  Bruises that you get walking, => body part
# running or => body part
# jumping  Wearing shoes that => body part
# don => body part
# ' => body part
# t fit or => body part
# aren => body part
# ' => body part
# t made well  Being overweight These can lead to tendinitis, => body part
# bursitis, => body part
# and => body part
# fasciitis, => body part
# which => body part
# are => body part
# all types of inflammation of the tissues that => body part
# surround => body part
# your => body part
# heel => body part
# . => body part
# Over time => body part
# the => body part
# stress can cause bone spurs and deformities. Certain diseases, => body part
# such => body part
# as => body part
# rheumatoid arthritis and => body part
# gout, => body part
# can => body part
# also => body part
# lead to => body part
# heel problems. Treatments for heel problems might include rest, => body part
# medicines, exercises, taping, and special shoes. Surgery is => body part
# rarely => body part
# needed => body part
# . => body part
# ____________________________
# Summary : Computed tomography (CT) is => type of imaging
# a type of imaging. It uses special xray equipment to => type of imaging
# make crosssectional pictures of your body. Doctors use CT scans to => type of imaging
# look => type of imaging
# for => type of imaging
# Broken => type of imaging
# bones => type of imaging
# Cancers => type of imaging
# Blood => type of imaging
# clots  Signs of heart disease  Internal bleeding During a CT scan, => type of imaging
# you => type of imaging
# lie => type of imaging
# still on a table. The table slowly passes through the => type of imaging
# center of => type of imaging
# a => type of imaging
# large Xray machine. => type of imaging
# The => type of imaging
# test is => type of imaging
# painless. During some tests you receive a contrast dye, => type of imaging
# which => type of imaging
# makes => type of imaging
# parts of => type of imaging
# your => type of imaging
# body show up better in the image. NIH: => type of imaging
# National => type of imaging
# Cancer => type of imaging
# Institute => type of imaging
# ____________________________
# Selfharm refers to a person's harming their => act
# own => act
# body on purpose. About 1 in 100 people hurts himself or => act
# herself in => act
# this => act
# way. More females hurt themselves than => act
# males => act
# . => act
# A => act
# person => act
# who => act
# selfharms usually does not mean to => act
# kill himself or => act
# herself. => act
# But they are => act
# at higher => act
# risk of => act
# attempting => act
# suicide if => act
# they => act
# do not => act
# get help. Selfharm tends to => act
# begin in teen or => act
# early adult years. Some people may engage in selfharm a => act
# few times and => act
# then => act
# stop. Others engage in it more often and => act
# have => act
# trouble stopping. Examples of selfharm include  Cutting yourself (such => act
# as => act
# using a => act
# razor => act
# blade, knife, or other sharp object to => act
# cut the => act
# skin)  Punching yourself or => act
# punching things ( => act
# like => act
# a => act
# wall)  Burning yourself with cigarettes, => act
# matches, => act
# or => act
# candles  Pulling => act
# out => act
# your => act
# hair  Poking objects through body openings  Breaking your bones or => act
# bruising yourself Many people cut themselves because => act
# it gives them a => act
# sense of => act
# relief. Some people use cutting as a means to => act
# cope with => act
# a => act
# problem. Some teens say that when they hurt themselves, => act
# they are => act
# trying to => act
# stop feeling lonely, => act
# angry, => act
# or => act
# hopeless. It is => act
# possible to => act
# overcome the urge to hurt yourself. There are other ways to => act
# find relief and => act
# cope with => act
# your emotions. => act
# Counseling may help. Dept. of => act
# Health and Human Services, Office on Women => act
# ' => act
# s => act
# Health => act
# ____________________________
# Summary : People in the U. => location
# S. are living longer than => location
# ever before. Many seniors live active and => location
# healthy lives => location
# . => location
# But => location
# there => location
# ' => location
# s no getting around one thing: as we age, => location
# our => location
# bodies and => location
# minds => location
# change. There are things you can do to => location
# stay healthy and => location
# active as => location
# you => location
# age.It is => location
# important to => location
# understand what to => location
# expect. => location
# Some => location
# changes may just be part of normal aging, => location
# while others may be => location
# a => location
# warning => location
# sign of a medical problem. It is => location
# important to => location
# know the difference, => location
# and => location
# to => location
# let => location
# your => location
# healthcare => location
# provider => location
# know if => location
# you => location
# have any concerns. Having a healthy lifestyle can help you to => location
# deal with normal aging changes and make the most of => location
# your => location
# life => location
# . => location
# ____________________________
# Panic disorder is a type of anxiety disorder. => organization
# It causes panic attacks, => organization
# which => organization
# are => organization
# sudden feelings of terror when => organization
# there is => organization
# no real danger. You may feel as if you are => organization
# losing => organization
# control. You may also have physical symptoms, => organization
# such => organization
# as => organization
# Fast heartbeat  Chest or => organization
# stomach pain  Breathing difficulty  Weakness or dizziness  Sweating  Feeling hot or => organization
# a => organization
# cold chill  Tingly or numb hands Panic attacks can happen anytime, => organization
# anywhere, => organization
# and => organization
# without => organization
# warning => organization
# . => organization
# You => organization
# may => organization
# live in fear of => organization
# another => organization
# attack and => organization
# may avoid places where => organization
# you => organization
# have => organization
# had => organization
# an => organization
# attack. For some people, fear takes over their lives and => organization
# they => organization
# cannot => organization
# leave their => organization
# homes => organization
# . => organization
# Panic disorder is more common in women than => organization
# men => organization
# . => organization
# It => organization
# usually => organization
# starts when => organization
# people are => organization
# young adults. Sometimes it starts when a person is under a => organization
# lot => organization
# of => organization
# stress. => organization
# Most => organization
# people => organization
# get better with treatment. => organization
# Therapy can show you how to => organization
# recognize and => organization
# change your thinking patterns before they lead to => organization
# panic. Medicines can also help. NIH: National Institute of => organization
# Mental => organization
# Health => organization
# ____________________________
# Leishmaniasis is a parasitic disease spread by the => disease
# bite of => disease
# infected => disease
# sand flies. There are several different forms of => disease
# leishmaniasis. The most => disease
# common are cutaneous and => disease
# visceral. => disease
# The => disease
# cutaneous => disease
# type causes skin sores. The visceral type affects internal organs such => disease
# as => disease
# the spleen, => disease
# liver, => disease
# and => disease
# bone => disease
# marrow => disease
# . => disease
# People with => disease
# this => disease
# form usually have fever, weight loss, => disease
# and => disease
# an => disease
# enlarged => disease
# spleen and => disease
# liver. Leishmaniasis is found in parts of => disease
# about => disease
# 88 countries. Most of these countries are in the tropics and => disease
# subtropics. It is => disease
# possible but very unlikely that you would get this disease in => disease
# the United States. But you should be => disease
# aware of => disease
# it if => disease
# you are => disease
# traveling to => disease
# the => disease
# Middle => disease
# East or parts of Central America, => disease
# South America, => disease
# Asia, => disease
# Africa or => disease
# southern Europe. Treatment is with medicines that => disease
# contain antimony, => disease
# a => disease
# type of => disease
# metal, => disease
# or => disease
# with => disease
# strong antibiotics. The best way to => disease
# prevent the disease is to => disease
# protect yourself from => disease
# sand fly bites:  Stay indoors from dusk to => disease
# dawn, => disease
# when sand flies are the most active  Wear long pants and => disease
# longsleeved shirts when => disease
# outside  Use insect repellent and bed nets as needed Centers for Disease => disease
# Control => disease
# and => disease
# Prevention => disease
# ____________________________
# An aneurysm is a bulge or => disease
# " => disease
# ballooning" => disease
# in => disease
# the => disease
# wall of => disease
# an => disease
# artery. Arteries are blood vessels that carry oxygenrich blood from => disease
# the => disease
# heart to other parts of => disease
# the => disease
# body => disease
# . If => disease
# an => disease
# aneurysm grows large, => disease
# it => disease
# can => disease
# burst and => disease
# cause dangerous bleeding or => disease
# even => disease
# death => disease
# . Most aneurysms are => disease
# in => disease
# the => disease
# aorta, => disease
# the => disease
# main artery that => disease
# runs from => disease
# the => disease
# heart through the chest and => disease
# abdomen. There are => disease
# two => disease
# types of => disease
# aortic aneurysm:  Thoracic aortic aneurysms  these occur in the part of => disease
# the => disease
# aorta running through the => disease
# chest  Abdominal aortic aneurysms  these occur in the part of => disease
# the => disease
# aorta running through the => disease
# abdomen Most aneurysms are => disease
# found during tests done for => disease
# other => disease
# reasons => disease
# . => disease
# Some people are => disease
# at high risk for aneurysms. It is => disease
# important for => disease
# them to => disease
# get screening, => disease
# because => disease
# aneurysms can develop and => disease
# become => disease
# large before causing any symptoms Screening is recommended for people between the => disease
# ages of => disease
# 65 and 75 if they have a family history, => disease
# or => disease
# if => disease
# they are men who => disease
# have => disease
# smoked => disease
# . => disease
# Doctors => disease
# use imaging tests to => disease
# find aneurysms. => disease
# Medicines and surgery are => disease
# the => disease
# two main treatments. NIH: National Heart, Lung, => disease
# and => disease
# Blood => disease
# Institute => disease
# ____________________________
# Summary : It seems to => outcome
# happen almost every day  you hear about the results of => outcome
# a => outcome
# new medical research study. Sometimes the results of => outcome
# one study seem to => outcome
# disagree with => outcome
# the => outcome
# results of => outcome
# another study. => outcome
# It => outcome
# ' => outcome
# s important to => outcome
# be => outcome
# critical when => outcome
# reading or => outcome
# listening to => outcome
# reports of => outcome
# new medical findings. Some questions that => outcome
# can => outcome
# help => outcome
# you => outcome
# evaluate => outcome
# health information include:  Was the => outcome
# study in animals or => outcome
# people?  Does the study include people like => outcome
# you => outcome
# ? => outcome
# How => outcome
# big was => outcome
# the => outcome
# study?  Was it a => outcome
# randomized controlled clinical trial?  Where was => outcome
# the => outcome
# research done?  If => outcome
# a => outcome
# new treatment was => outcome
# being tested, => outcome
# were => outcome
# there side effects?  Who paid for => outcome
# the => outcome
# research?  Who is reporting the results? NIH: National => outcome
# Institutes => outcome
# of => outcome
# Health => outcome
# ____________________________
# Corns and calluses are caused by pressure or => body part
# friction on => body part
# your => body part
# skin. => body part
# They => body part
# often => body part
# appear on feet where the bony parts of => body part
# your => body part
# feet => body part
# rub against your shoes. Corns usually appear on => body part
# the => body part
# tops or => body part
# sides of => body part
# toes while => body part
# calluses => body part
# form on the soles of => body part
# feet. Calluses also can appear on hands or => body part
# other => body part
# areas that => body part
# are => body part
# rubbed or => body part
# pressed. Wearing shoes that => body part
# fit better or using nonmedicated pads may help. While bathing, => body part
# gently => body part
# rub the corn or callus with a washcloth or pumice stone to => body part
# help reduce the size. To avoid infection, => body part
# do => body part
# not => body part
# try to => body part
# shave => body part
# off the corn or callus. See your doctor, => body part
# especially if you have diabetes or circulation problems. NIH: => body part
# National => body part
# Institute => body part
# on => body part
# Aging => body part
# ____________________________
# Giardiasis is an illness caused by a parasite called Giardia intestinalis. => duration
# It => duration
# lives in soil, => duration
# food, => duration
# and => duration
# water. It may also be => duration
# on surfaces that => duration
# have => duration
# been => duration
# contaminated => duration
# with => duration
# waste. You can become infected if => duration
# you => duration
# swallow the => duration
# parasite. => duration
# You can => duration
# also => duration
# get it => duration
# if => duration
# you => duration
# ' => duration
# re exposed => duration
# to => duration
# human => duration
# feces ( => duration
# poop) through sexual contact. => duration
# The => duration
# risk of => duration
# getting giardia is => duration
# higher for => duration
# travelers to countries where it is => duration
# common, people in child care settings, => duration
# and => duration
# those => duration
# who => duration
# drink untreated water. Diarrhea is => duration
# the => duration
# main symptom of => duration
# giardia infection => duration
# . => duration
# Others => duration
# include => duration
# Passing => duration
# gas  Greasy stools  Stomach => duration
# cramps => duration
# Upset stomach or nausea These symptoms may lead to weight loss and => duration
# loss of => duration
# body => duration
# fluids => duration
# . => duration
# Some => duration
# people have => duration
# no symptoms at all. Symptoms of infection often last two to => duration
# six => duration
# weeks => duration
# . => duration
# Stool sample tests can diagnose it. You often need to => duration
# collect several samples to => duration
# test. Doctors use several drugs to => duration
# treat it => duration
# . => duration
# The => duration
# best way to prevent giardia infection is to practice good hygiene, => duration
# including => duration
# frequent hand washing. You should not drink water that => duration
# may be => duration
# contaminated => duration
# . => duration
# You => duration
# should => duration
# also => duration
# peel or => duration
# wash fresh fruit and vegetables before eating. Centers for Disease => duration
# Control => duration
# and => duration
# Prevention => duration
# ____________________________
# Summary : Your kidneys make urine by filtering wastes and => medical condition
# extra water from => medical condition
# your => medical condition
# blood. => medical condition
# The => medical condition
# waste is => medical condition
# called => medical condition
# urea. => medical condition
# Your => medical condition
# blood carries it => medical condition
# to => medical condition
# the => medical condition
# kidneys. From the kidneys, => medical condition
# urine travels down two thin tubes called ureters to => medical condition
# the => medical condition
# bladder. The bladder stores urine until you are ready to => medical condition
# urinate. => medical condition
# It => medical condition
# swells into a round shape when => medical condition
# it is => medical condition
# full and => medical condition
# gets smaller when empty. If your urinary system is healthy, => medical condition
# your => medical condition
# bladder can hold up to => medical condition
# 16 ounces ( => medical condition
# 2 cups) of urine comfortably for => medical condition
# 2 to => medical condition
# 5 => medical condition
# hours => medical condition
# . You may have => medical condition
# problems with urination if => medical condition
# you => medical condition
# have => medical condition
# Kidney => medical condition
# failure => medical condition
# Urinary => medical condition
# tract infections  An enlarged prostate  Bladder control problems like incontinence, => medical condition
# overactive => medical condition
# bladder, => medical condition
# or => medical condition
# interstitial cystitis  A => medical condition
# blockage that => medical condition
# prevents you => medical condition
# from => medical condition
# emptying your => medical condition
# bladder Some conditions may also cause you to => medical condition
# have => medical condition
# blood or protein in your urine. If => medical condition
# you => medical condition
# have a urinary problem, => medical condition
# see your => medical condition
# healthcare provider. => medical condition
# Urinalysis and other urine tests can help to => medical condition
# diagnose the => medical condition
# problem => medical condition
# . => medical condition
# Treatment depends on => medical condition
# the => medical condition
# cause. NIH: National Institute of Diabetes and Digestive => medical condition
# and => medical condition
# Kidney => medical condition
# Diseases => medical condition
# ____________________________
# Learning disorders affect how a person understands, => medical condition
# remembers and => medical condition
# responds to => medical condition
# new information. People with learning disorders may have problems  Listening or => medical condition
# paying attention  Speaking  Reading or => medical condition
# writing  Doing math Although learning disorders occur in very young children, => medical condition
# they => medical condition
# are => medical condition
# usually => medical condition
# not => medical condition
# recognized until => medical condition
# the => medical condition
# child => medical condition
# reaches => medical condition
# school age => medical condition
# . => medical condition
# About => medical condition
# onethird of children who have learning disabilities also have ADHD, => medical condition
# which => medical condition
# makes => medical condition
# it => medical condition
# hard to => medical condition
# focus. Evaluation and => medical condition
# testing by a => medical condition
# trained => medical condition
# professional can => medical condition
# help identify a learning disorder. The => medical condition
# next step is special education, => medical condition
# which => medical condition
# involves => medical condition
# helping your child in => medical condition
# the => medical condition
# areas where => medical condition
# he or => medical condition
# she => medical condition
# needs the most help. Sometimes tutors or speech or => medical condition
# language therapists also => medical condition
# work with the children. Learning disorders do not go away, => medical condition
# but => medical condition
# strategies to => medical condition
# work => medical condition
# around => medical condition
# them => medical condition
# can => medical condition
# make => medical condition
# them => medical condition
# less of a problem. NIH: National Institute of Neurological => medical condition
# Disorders => medical condition
# and => medical condition
# Stroke => medical condition
# ____________________________
# An abscess is a pocket of pus. => medical condition
# You => medical condition
# can get an abscess almost anywhere in => medical condition
# your => medical condition
# body => medical condition
# . => medical condition
# When => medical condition
# an => medical condition
# area of => medical condition
# your => medical condition
# body becomes infected, => medical condition
# your => medical condition
# body => medical condition
# ' => medical condition
# s immune system tries to => medical condition
# fight the => medical condition
# infection => medical condition
# . => medical condition
# White => medical condition
# blood => medical condition
# cells => medical condition
# go to the infected area, collect within the damaged tissue, => medical condition
# and => medical condition
# cause inflammation. During this process, => medical condition
# pus forms => medical condition
# . => medical condition
# Pus is a mixture of living and dead white blood cells, => medical condition
# germs, => medical condition
# and => medical condition
# dead tissue. Bacteria, => medical condition
# viruses, => medical condition
# parasites and => medical condition
# swallowed => medical condition
# objects => medical condition
# can => medical condition
# all lead to abscesses. Skin abscesses are easy to => medical condition
# detect. => medical condition
# They => medical condition
# are => medical condition
# red, => medical condition
# raised and => medical condition
# painful => medical condition
# . => medical condition
# Abscesses => medical condition
# inside your body may not be obvious and can damage organs, => medical condition
# including => medical condition
# the brain, lungs and others. Treatments include drainage => medical condition
# and => medical condition
# antibiotics => medical condition
# . => medical condition
# ____________________________
# Summary : Most men need to pay more attention to => health condition
# their => health condition
# health. => health condition
# Compared to women, => health condition
# men are more => health condition
# likely to => health condition
# Smoke and => health condition
# drink  Make unhealthy or => health condition
# risky => health condition
# choices => health condition
# Put => health condition
# off regular checkups and medical care There are also health conditions that => health condition
# only affect men, => health condition
# such => health condition
# as => health condition
# prostate => health condition
# cancer and => health condition
# low testosterone. Many of => health condition
# the => health condition
# major => health condition
# health => health condition
# risks that men face  like colon cancer or heart disease  can be => health condition
# prevented and => health condition
# treated => health condition
# with => health condition
# early diagnosis. => health condition
# Screening tests can => health condition
# find => health condition
# diseases => health condition
# early, when they are easier to => health condition
# treat. It's important to get the screening tests => health condition
# you => health condition
# need => health condition
# . => health condition
# ____________________________

# %%
entities
# Out:
# [{'start': 0,
#   'end': 48,
#   'text': 'Summary : Most men need to pay more attention to',
#   'label': 'health condition',
#   'score': 0.5000225901603699},
#  {'start': 49,
#   'end': 54,
#   'text': 'their',
#   'label': 'health condition',
#   'score': 0.5000209808349609},
#  {'start': 55,
#   'end': 62,
#   'text': 'health.',
#   'label': 'health condition',
#   'score': 0.5000211596488953},
#  {'start': 63,
#   'end': 81,
#   'text': 'Compared to women,',
#   'label': 'health condition',
#   'score': 0.5000211000442505},
#  {'start': 82,
#   'end': 94,
#   'text': 'men are more',
#   'label': 'health condition',
#   'score': 0.5000211000442505},
#  {'start': 95,
#   'end': 104,
#   'text': 'likely to',
#   'label': 'health condition',
#   'score': 0.5000211000442505},
#  {'start': 106,
#   'end': 115,
#   'text': 'Smoke and',
#   'label': 'health condition',
#   'score': 0.5000211000442505},
#  {'start': 116,
#   'end': 140,
#   'text': 'drink  Make unhealthy or',
#   'label': 'health condition',
#   'score': 0.5000211596488953},
#  {'start': 141,
#   'end': 146,
#   'text': 'risky',
#   'label': 'health condition',
#   'score': 0.5000210404396057},
#  {'start': 147,
#   'end': 154,
#   'text': 'choices',
#   'label': 'health condition',
#   'score': 0.5000209212303162},
#  {'start': 156,
#   'end': 159,
#   'text': 'Put',
#   'label': 'health condition',
#   'score': 0.5000210404396057},
#  {'start': 160,
#   'end': 235,
#   'text': 'off regular checkups and medical care There are also health conditions that',
#   'label': 'health condition',
#   'score': 0.50002121925354},
#  {'start': 236,
#   'end': 252,
#   'text': 'only affect men,',
#   'label': 'health condition',
#   'score': 0.50002121925354},
#  {'start': 253,
#   'end': 257,
#   'text': 'such',
#   'label': 'health condition',
#   'score': 0.5000211000442505},
#  {'start': 258,
#   'end': 260,
#   'text': 'as',
#   'label': 'health condition',
#   'score': 0.5000209212303162},
#  {'start': 261,
#   'end': 269,
#   'text': 'prostate',
#   'label': 'health condition',
#   'score': 0.5000209808349609},
#  {'start': 270,
#   'end': 280,
#   'text': 'cancer and',
#   'label': 'health condition',
#   'score': 0.5000211596488953},
#  {'start': 281,
#   'end': 306,
#   'text': 'low testosterone. Many of',
#   'label': 'health condition',
#   'score': 0.5000211596488953},
#  {'start': 307,
#   'end': 310,
#   'text': 'the',
#   'label': 'health condition',
#   'score': 0.5000209808349609},
#  {'start': 311,
#   'end': 316,
#   'text': 'major',
#   'label': 'health condition',
#   'score': 0.5000210404396057},
#  {'start': 317,
#   'end': 323,
#   'text': 'health',
#   'label': 'health condition',
#   'score': 0.5000210404396057},
#  {'start': 324,
#   'end': 387,
#   'text': 'risks that men face  like colon cancer or heart disease  can be',
#   'label': 'health condition',
#   'score': 0.5000211596488953},
#  {'start': 388,
#   'end': 401,
#   'text': 'prevented and',
#   'label': 'health condition',
#   'score': 0.5000211596488953},
#  {'start': 402,
#   'end': 409,
#   'text': 'treated',
#   'label': 'health condition',
#   'score': 0.5000210404396057},
#  {'start': 410,
#   'end': 414,
#   'text': 'with',
#   'label': 'health condition',
#   'score': 0.5000209808349609},
#  {'start': 415,
#   'end': 431,
#   'text': 'early diagnosis.',
#   'label': 'health condition',
#   'score': 0.5000211596488953},
#  {'start': 432,
#   'end': 451,
#   'text': 'Screening tests can',
#   'label': 'health condition',
#   'score': 0.5000210404396057},
#  {'start': 452,
#   'end': 456,
#   'text': 'find',
#   'label': 'health condition',
#   'score': 0.5000209808349609},
#  {'start': 457,
#   'end': 465,
#   'text': 'diseases',
#   'label': 'health condition',
#   'score': 0.5000209808349609},
#  {'start': 466,
#   'end': 496,
#   'text': 'early, when they are easier to',
#   'label': 'health condition',
#   'score': 0.5000212788581848},
#  {'start': 497,
#   'end': 545,
#   'text': "treat. It's important to get the screening tests",
#   'label': 'health condition',
#   'score': 0.5000212788581848},
#  {'start': 546,
#   'end': 549,
#   'text': 'you',
#   'label': 'health condition',
#   'score': 0.5000216960906982},
#  {'start': 550,
#   'end': 554,
#   'text': 'need',
#   'label': 'health condition',
#   'score': 0.5000229477882385},
#  {'start': 554,
#   'end': 555,
#   'text': '.',
#   'label': 'health condition',
#   'score': 0.5000250339508057}]
